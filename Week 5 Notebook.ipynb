# %% [markdown]
# # *Battle of neighbourhoods*

# %% [markdown]
# ## Introduction & Business Background
#
# An international hotel chain ("IHC") is looking to set up a new hotel in Singapore. This is its first physical establishment in the Asian island country. In the planning phase, the management has considered two potential locations, namely, Sentosa Island or Marina Bay Area. Sentosa is a resort island located at the south of Singapore and connected to the main island via a bridge. This island is mostly frequented by families on holiday. Marina Bay Area is the central business district of the city and it is also closely located to many other attractions in the city.
#
# The primary customer group for IHC are tourists looking for leisure activities as well as new experiences in difference countries. IHC is also one of the world's premium hotel brands which all of its properties rated five stars. Therefore, one of the main consideration of for the location is its proximirty to attarctions nearby. Given Singapore is a small island nation and both locations are easily accessible, the management has approached us to determine which location would be a better option to set up IHC's first Hotel in Singapore.

# %% [markdown]
# ## Date requirements

# %% [markdown]
# **1. GPS coordinates of the 2 locations for consideration.**
# These coordinates forms the basis of our analysis and provide geographical location in our model
#
# **2. Number of attractions within 1km radius**
# This data provide us information on how close the hotel will be to attractions in the country. The higher the number, the better the location.
#
# **3. Number of restaurants within 1km radius**
# This data provide us information on the number of restaurants. As IHC's customers are mainly tourists, dining out is an important part of leisure travel and it is better that the hotel is conveniently located within proximity of good restaurants.
#
# **4. Number of bars/clubs within 1km radius**
# This data provide us information on the number of bars. As IHC's customers are mainly tourists seeking new experiences, a vibrant night life is an important part of leisure travel and it is better that the hotel is conveniently located within proximity of such establishments.
#
# **5. Number of other 5 stars hotels within 1km radius**
# This data shows the intensity of competition within the selected location. If there are more 5 stars hotels in the location, it indicates that IHC will face tougher competition in the location and thus, making the locating less preferable

# %% [markdown]
# ## Methodology
#
# Data number 1 will be used as the basis location to retrieve information on Foursquare.com
# Data number 2 to 4 carries positive values and will be used as a summation of scores. Data number 5 carries negative scores and will be added to the summation of data numner 1 to 4. The total score of both location will be compared side by side. Location with higher score will be selected as the preferred choice. The data will be used to populate the following decision matrix:
#
# Location | Number of attractions | Number of restaurants | Number of bars/clubs | Number of 5* hotel | Sum of scores |
# --- | --- | --- | --- | --- | --- |
# **Marina Bay** | data 2 | data 3 | data 4 | data 5 | Sum data 2 to 4 - data 5 |
# **Sentosa** | data 2 | data 3 | data 4 | data 5 | Sum data 2 to 4 - data 5 |

# %% [markdown]
# ## Results and codes

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = '4AXFFWDVV2IY5OMNSKE1N3TGLS5SYHYGKUK5Z3WV54NBV3HZ' 
CLIENT_SECRET = '4TH3MEP5LRPSIQTVRMVAFOFBY0LRP422TFSML1BQCUDL4M4J'
VERSION = '20200104'
LIMIT = 100
radius = 1000
#Key in the latitude and longitude of the two intended location
latitude_sentosa=1.250111
longitude_sentosa = 103.830933
latitude_marina=1.283000
longitude_marina=103.857900

# %%
#foursquare call for Marina Bay Location data 2
search_query = 'Attractions'
url_marina = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_marina, longitude_marina, VERSION, search_query, radius, LIMIT)

results_marina_2 = requests.get(url_marina).json()

# assign relevant part of JSON to venues
venues = results_marina_2['response']['venues']

# tranform venues into a dataframe
df_marina_2 = json_normalize(venues)
df_marina_2.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ff931735', 'name': 'C...    False
#
#                          id location.cc location.country  location.distance  \
# 0  51aec75a498e8b574b20f005          SG        Singapore                345
#
#   location.formattedAddress  \
# 0               [Singapore]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 1.285874186724561...      1.285874
#
#    location.lng                            name    referralId
# 0    103.859067  IAAPA - Asian Attractions Expo  v-1586276205

# %%
#foursquare call for Sentosa Location data 2
url_sentosa = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_sentosa, longitude_sentosa, VERSION, search_query, radius, LIMIT)

results_sentosa_2 = requests.get(url_sentosa).json()

# assign relevant part of JSON to venues
venues = results_sentosa_2['response']['venues']

# tranform venues into a dataframe
df_sentosa_2 = json_normalize(venues)
df_sentosa_2.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#foursquare call for Marina Bay Location data 3
search_query = 'Restaurants'
url_marina = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_marina, longitude_marina, VERSION, search_query, radius, LIMIT)

results_marina_3 = requests.get(url_marina).json()

# assign relevant part of JSON to venues
venues = results_marina_3['response']['venues']

# tranform venues into a dataframe
df_marina_3 = json_normalize(venues)
df_marina_3.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 2  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...    False
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
# 4                                                 []    False
# 5  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
#
#                          id                     location.address location.cc  \
# 0  51a04cb2498e30596041bfba                      Fullertoun Road          SG
# 1  4c49289f76fbb71354ce5f74  17 Boon Tat Street Singapore 069618          SG
# 2  4d86da295e70224b1dd93e09          Lau Pa Sat, 18 Raffles Quay          SG
# 3  4e214810b0fbdf9ba7a86028                                  NaN          SG
# 4  5131e5cde4b08f70edd87be0                                  NaN          SG
# 5  4e55f1f9227140cf12eeca1b                 Food Republic Suntec          SG
#
#   location.city location.country        location.crossStreet  \
# 0     Singapore        Singapore  BrandalPakis³⁴⁷ punya Area
# 1     Singapore        Singapore                         NaN
# 2     Singapore        Singapore                         NaN
# 3           NaN        Singapore                         NaN
# 4           NaN        Singapore                         NaN
# 5     Singapore        Singapore                         NaN
#
#    location.distance                          location.formattedAddress  \
# 0                661  [Fullertoun Road (BrandalPakis³⁴⁷ punya Area),...
# 1               1067  [17 Boon Tat Street Singapore 069618, 069618, ...
# 2                833   [Lau Pa Sat, 18 Raffles Quay, 048582, Singapore]
# 3                917                                        [Singapore]
# 4                964                                        [Singapore]
# 5               1139                  [Food Republic Suntec, Singapore]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 1.2868517, 'lng':...      1.286852
# 1  [{'label': 'display', 'lat': 1.281569, 'lng': ...      1.281569
# 2  [{'label': 'display', 'lat': 1.281684031671678...      1.281684
# 3  [{'label': 'display', 'lat': 1.288863, 'lng': ...      1.288863
# 4  [{'label': 'display', 'lat': 1.289267566975015...      1.289268
# 5  [{'label': 'display', 'lat': 1.293236259399722...      1.293236
#
#    location.lng location.postalCode  \
# 0    103.853376                 NaN
# 1    103.848413              069618
# 2    103.850529              048582
# 3    103.852108                 NaN
# 4    103.851910                 NaN
# 5    103.858127                 NaN
#
#                                          name    referralId
# 0                   Fast Food Restaurants ³⁴⁷  v-1586276212
# 1             BI WON KOREAN RESTAURANTS & PUB  v-1586276212
# 2                         Komala's Restaurant  v-1586276212
# 3                     Verandah Restaurant@SCC  v-1586276212
# 4  O' Learys Bar & Restaurant Singapore Flyer  v-1586276212
# 5               Fortunate Restaurant @ Suntec  v-1586276212

# %%
#foursquare call for Sentosa Location data 3
url_sentosa = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_sentosa, longitude_sentosa, VERSION, search_query, radius, LIMIT)

results_sentosa_3 = requests.get(url_sentosa).json()

# assign relevant part of JSON to venues
venues = results_sentosa_3['response']['venues']

# tranform venues into a dataframe
df_sentosa_3 = json_normalize(venues)
df_sentosa_3.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d121941735', 'name': 'L...    False
#
#                          id    location.address location.cc   location.city  \
# 0  4d21ba556e8c3704f41705a0                 NaN          SG             NaN
# 1  4d09b9d0e023224bf47b5cd2  2 Bukit Manis Road          SG  Sentosa Island
#
#   location.country  location.distance  \
# 0        Singapore                841
# 1        Singapore                410
#
#                  location.formattedAddress  \
# 0                              [Singapore]
# 1  [2 Bukit Manis Road, 099891, Singapore]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 1.243057, 'lng': ...      1.243057
# 1  [{'label': 'display', 'lat': 1.249123641408845...      1.249124
#
#    location.lng location.postalCode  \
# 0    103.828224                 NaN
# 1    103.827380              099891
#
#                                         name    referralId
# 0       Different Taste Cafe And Restaurants  v-1586276217
# 1  Pavilion Restaurant @Sentosa Resort & Spa  v-1586276217

# %%
#foursquare call for Marina Bay Location data 4
search_query = 'Bars'
url_marina = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_marina, longitude_marina, VERSION, search_query, radius, LIMIT)

results_marina_4 = requests.get(url_marina).json()

# assign relevant part of JSON to venues
venues = results_marina_4['response']['venues']

# tranform venues into a dataframe
df_marina_4 = json_normalize(venues)
df_marina_4.head(15)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d112941735', 'name': 'J...    False
# 1  [{'id': '4bf58dd8d48988d16f941735', 'name': 'H...    False
# 2                                                 []    False
# 3  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...    False
# 5  [{'id': '55a59bace4b013909087cb24', 'name': 'R...    False
# 6                                                 []    False
# 7  [{'id': '4bf58dd8d48988d123951735', 'name': 'S...    False
# 8  [{'id': '55a59bace4b013909087cb24', 'name': 'R...    False
#
#                          id        location.address location.cc location.city  \
# 0  5859e9aa8ab03f2c8ec84848                     NaN          SG           NaN
# 1  4f3b3616e4b0b0c433730206                     NaN          SG           NaN
# 2  4d1d2cabdd6a236a805c1b38        Marina Bay Sands          SG           NaN
# 3  55a7aad1498e00b4276e5467                     NaN          SG           NaN
# 4  4dae90f66a23e6c9348c7526                     NaN          SG     Singapore
# 5  4fc31c49e4b0f6b4ee90f3be  61 Circular Rd, #01-01          SG     Singapore
# 6  4e05772f2271dfa46ba2cdb6                     NaN          SG     Singapore
# 7  4e19711f62e12640d87f3835                     NaN          SG           NaN
# 8  51bfe318498ebafa0c2354d4       17 Stanley Street          SG           NaN
#
#   location.country  location.distance  \
# 0        Singapore                616
# 1        Singapore                602
# 2        Singapore                403
# 3        Singapore                680
# 4        Singapore                904
# 5        Singapore               1023
# 6        Singapore               1015
# 7        Singapore               1096
# 8        Singapore               1125
#
#                      location.formattedAddress  \
# 0                                  [Singapore]
# 1                                  [Singapore]
# 2                [Marina Bay Sands, Singapore]
# 3                                  [Singapore]
# 4                                  [Singapore]
# 5  [61 Circular Rd, #01-01, 049415, Singapore]
# 6                                  [Singapore]
# 7                                  [Singapore]
# 8               [17 Stanley Street, Singapore]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 1.281288, 'lng': ...      1.281288
# 1  [{'label': 'display', 'lat': 1.28065, 'lng': 1...      1.280650
# 2  [{'label': 'display', 'lat': 1.283821545256769...      1.283822
# 3  [{'label': 'display', 'lat': 1.281950833475773...      1.281951
# 4  [{'label': 'display', 'lat': 1.289441905306958...      1.289442
# 5  [{'label': 'display', 'lat': 1.286182976851747...      1.286183
# 6  [{'label': 'display', 'lat': 1.292089821682831...      1.292090
# 7  [{'label': 'display', 'lat': 1.286350606133991...      1.286351
# 8  [{'label': 'display', 'lat': 1.280562004137643...      1.280562
#
#    location.lng location.postalCode                                  name  \
# 0    103.852628                 NaN                       Lean Juice Bars
# 1    103.853020                 NaN            Monkey Bars @ Change Alley
# 2    103.861434                 NaN                       Bar Store @ 55M
# 3    103.863924                 NaN  Rooftop Bar | Supertree By Indochine
# 4    103.862860                 NaN            ABSS Bar @ Singapore Flyer
# 5    103.849277              049415                      Ramen Bar Suzuki
# 6    103.858671                 NaN                         BQT Bar Store
# 7    103.848638                 NaN                 Gold Bar Smoking Area
# 8    103.848088                 NaN                      Ramen Bar Suzuki
#
#      referralId
# 0  v-1586276242
# 1  v-1586276242
# 2  v-1586276242
# 3  v-1586276242
# 4  v-1586276242
# 5  v-1586276242
# 6  v-1586276242
# 7  v-1586276242
# 8  v-1586276242

# %%
#foursquare call for Sentosa Location data 4
url_sentosa = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_sentosa, longitude_sentosa, VERSION, search_query, radius, LIMIT)

results_sentosa_4 = requests.get(url_sentosa).json()

# assign relevant part of JSON to venues
venues = results_sentosa_4['response']['venues']

# tranform venues into a dataframe
df_sentosa_4 = json_normalize(venues)
df_sentosa_4.head(15)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#foursquare call for Marina Bay Location data 5
search_query = 'Hotels'
url_marina = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_marina, longitude_marina, VERSION, search_query, radius, LIMIT)

results_marina_5 = requests.get(url_marina).json()

# assign relevant part of JSON to venues
venues = results_marina_5['response']['venues']

# tranform venues into a dataframe
df_marina_5 = json_normalize(venues)
df_marina_5.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 3   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 4   [{'id': '4bf58dd8d48988d174941735', 'name': 'C...    False
# 5   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 6                                                  []    False
# 7   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 8   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 9                                                  []    False
# 10                                                 []    False
# 11  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 12  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 13  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 14  [{'id': '4bf58dd8d48988d132951735', 'name': 'H...    False
# 15  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 16  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
#
#                           id     location.address location.cc location.city  \
# 0   5ddcc235de3eae000888b567       2 Temasek Blvd          SG     Singapore
# 1   4d7b74e55a396dcbc1675ffb                  NaN          SG     Singapore
# 2   4ec05f527ee54e4cd2f3ba91                  NaN          SG           NaN
# 3   4ec31f4029c2f92bf5acb510                  NaN          SG           NaN
# 4   4eae7e45be7bd46a7be1fba2                  NaN          SG           NaN
# 5   4ec05fc30aaf6450baf67666                  NaN          SG     Singapore
# 6   4d1976c2e190721ec6c32921   80 Bras Basah Road          SG     Singapore
# 7   4d1af71b83c5a1cde804284e                  NaN          SG           NaN
# 8   4e8fed436da174e28e10944b     Marina bay sands          SG     Singapore
# 9   4d2d835a762fa1432fbd7964         Fullerton Rd          SG     Singapore
# 10  5872d48bea29b87b865729d6                  NaN          SG           NaN
# 11  4e2fd0dc45ddcf0f5c864797                  NaN          SG           NaN
# 12  5d8240d0dcfa830008b416cc     5 Raffles Avenue          SG     Singapore
# 13  5082cd97e4b06166970218bd                  NaN          SG           NaN
# 14  4d4d01b89ee1a35d371021df      6 Raffles Blvd.          SG     Singapore
# 15  4efbca5b7ee59da371a33838  7 Raffles Boulevard          SG     Singapore
# 16  4d2ec141a6df6dcb244fdc7a                  NaN          SG           NaN
#
#    location.country location.crossStreet  location.distance  \
# 0         Singapore                  NaN                217
# 1         Singapore                  NaN                572
# 2         Singapore                  NaN                780
# 3         Singapore                  NaN                906
# 4         Singapore                  NaN                909
# 5         Singapore                  NaN               1002
# 6         Singapore                  NaN               1250
# 7         Singapore                  NaN               1237
# 8         Singapore                  NaN                106
# 9         Singapore                  NaN                643
# 10        Singapore                  NaN                656
# 11        Singapore                  NaN                645
# 12        Singapore                  NaN                773
# 13        Singapore                  NaN                970
# 14        Singapore                  NaN               1017
# 15        Singapore               Marina               1025
# 16        Singapore                  NaN               1004
#
#                     location.formattedAddress  \
# 0         [2 Temasek Blvd, 038982, Singapore]
# 1                                 [Singapore]
# 2                                 [Singapore]
# 3                                 [Singapore]
# 4                                 [Singapore]
# 5                                 [Singapore]
# 6             [80 Bras Basah Road, Singapore]
# 7                         [179101, Singapore]
# 8               [Marina bay sands, Singapore]
# 9                   [Fullerton Rd, Singapore]
# 10                                [Singapore]
# 11                                [Singapore]
# 12      [5 Raffles Avenue, 039797, Singapore]
# 13                                [Singapore]
# 14               [6 Raffles Blvd., Singapore]
# 15  [7 Raffles Boulevard (Marina), Singapore]
# 16                                [Singapore]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 1.2813332, 'lng':...      1.281333
# 1   [{'label': 'display', 'lat': 1.286801, 'lng': ...      1.286801
# 2   [{'label': 'display', 'lat': 1.280180160990135...      1.280180
# 3   [{'label': 'display', 'lat': 1.279713939349647...      1.279714
# 4   [{'label': 'display', 'lat': 1.279697, 'lng': ...      1.279697
# 5   [{'label': 'display', 'lat': 1.279528329559382...      1.279528
# 6   [{'label': 'display', 'lat': 1.293636, 'lng': ...      1.293636
# 7   [{'label': 'display', 'lat': 1.293512511970212...      1.293513
# 8   [{'label': 'display', 'lat': 1.282267807028707...      1.282268
# 9   [{'label': 'display', 'lat': 1.286377712140318...      1.286378
# 10  [{'label': 'display', 'lat': 1.2815793, 'lng':...      1.281579
# 11  [{'label': 'display', 'lat': 1.286153548140678...      1.286154
# 12  [{'label': 'display', 'lat': 1.289948, 'lng': ...      1.289948
# 13  [{'label': 'display', 'lat': 1.276589986697232...      1.276590
# 14  [{'label': 'display', 'lat': 1.292024477552945...      1.292024
# 15  [{'label': 'display', 'lat': 1.292205655140051...      1.292206
# 16  [{'label': 'display', 'lat': 1.292024392507780...      1.292024
#
#     location.lng location.postalCode  \
# 0     103.858924              038982
# 1     103.854436                 NaN
# 2     103.851480                 NaN
# 3     103.850444                 NaN
# 4     103.850430                 NaN
# 5     103.849589                 NaN
# 6     103.854296                 NaN
# 7     103.854290              179101
# 8     103.858513                 NaN
# 9     103.853207                 NaN
# 10    103.863621                 NaN
# 11    103.853035                 NaN
# 12    103.858022              039797
# 13    103.863812                 NaN
# 14    103.856457                 NaN
# 15    103.858138                 NaN
# 16    103.858014                 NaN
#
#                                                  name    referralId  \
# 0                                Laxury Magnum Hotels  v-1586276253
# 1                                      Merlion Hotels  v-1586276253
# 2                            Montigo Hotels & Resorts  v-1586276253
# 3      Aqua Voyage , A Member Of KOP Hotels & Resorts  v-1586276253
# 4                                KOP Hotels & Resorts  v-1586276253
# 5                           Franklyn Hotels & Resorts  v-1586276253
# 6                        RC Hotels Female Locker Room  v-1586276253
# 7                                  RC Hotels Tuckshop  v-1586276253
# 8                  Marine Bay Sands Hotel Storey 2113  v-1586276253
# 9                 Gym @ The Fullerton Hotel Singapore  v-1586276253
# 10                              Mahadria Hotel Serang  v-1586276253
# 11  East Garden Foyer @ The Fullerton Hotel Singapore  v-1586276253
# 12  Morton's The Steakhouse at Mandarin Oriental H...  v-1586276253
# 13              Marina bay sands VVIP Hotel singapore  v-1586276253
# 14                Marina Mandarin Hotel Swimming Pool  v-1586276253
# 15         Global Kitchen Pan Pacific Hotel Singapore  v-1586276253
# 16        Pacific Cafe @ Pan Pacific Hotel Singaporey  v-1586276253
#
#    venuePage.id
# 0     572011888
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
#foursquare call for Sentosa Location data 5
url_sentosa = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_sentosa, longitude_sentosa, VERSION, search_query, radius, LIMIT)

results_sentosa_5 = requests.get(url_sentosa).json()

# assign relevant part of JSON to venues
venues = results_marina_5['response']['venues']

# tranform venues into a dataframe
df_sentosa_5 = json_normalize(venues)
df_sentosa_5.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 3   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 4   [{'id': '4bf58dd8d48988d174941735', 'name': 'C...    False
# 5   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 6                                                  []    False
# 7   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 8   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 9                                                  []    False
# 10                                                 []    False
# 11  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 12  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 13  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 14  [{'id': '4bf58dd8d48988d132951735', 'name': 'H...    False
# 15  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 16  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
#
#                           id     location.address location.cc location.city  \
# 0   5ddcc235de3eae000888b567       2 Temasek Blvd          SG     Singapore
# 1   4d7b74e55a396dcbc1675ffb                  NaN          SG     Singapore
# 2   4ec05f527ee54e4cd2f3ba91                  NaN          SG           NaN
# 3   4ec31f4029c2f92bf5acb510                  NaN          SG           NaN
# 4   4eae7e45be7bd46a7be1fba2                  NaN          SG           NaN
# 5   4ec05fc30aaf6450baf67666                  NaN          SG     Singapore
# 6   4d1976c2e190721ec6c32921   80 Bras Basah Road          SG     Singapore
# 7   4d1af71b83c5a1cde804284e                  NaN          SG           NaN
# 8   4e8fed436da174e28e10944b     Marina bay sands          SG     Singapore
# 9   4d2d835a762fa1432fbd7964         Fullerton Rd          SG     Singapore
# 10  5872d48bea29b87b865729d6                  NaN          SG           NaN
# 11  4e2fd0dc45ddcf0f5c864797                  NaN          SG           NaN
# 12  5d8240d0dcfa830008b416cc     5 Raffles Avenue          SG     Singapore
# 13  5082cd97e4b06166970218bd                  NaN          SG           NaN
# 14  4d4d01b89ee1a35d371021df      6 Raffles Blvd.          SG     Singapore
# 15  4efbca5b7ee59da371a33838  7 Raffles Boulevard          SG     Singapore
# 16  4d2ec141a6df6dcb244fdc7a                  NaN          SG           NaN
#
#    location.country location.crossStreet  location.distance  \
# 0         Singapore                  NaN                217
# 1         Singapore                  NaN                572
# 2         Singapore                  NaN                780
# 3         Singapore                  NaN                906
# 4         Singapore                  NaN                909
# 5         Singapore                  NaN               1002
# 6         Singapore                  NaN               1250
# 7         Singapore                  NaN               1237
# 8         Singapore                  NaN                106
# 9         Singapore                  NaN                643
# 10        Singapore                  NaN                656
# 11        Singapore                  NaN                645
# 12        Singapore                  NaN                773
# 13        Singapore                  NaN                970
# 14        Singapore                  NaN               1017
# 15        Singapore               Marina               1025
# 16        Singapore                  NaN               1004
#
#                     location.formattedAddress  \
# 0         [2 Temasek Blvd, 038982, Singapore]
# 1                                 [Singapore]
# 2                                 [Singapore]
# 3                                 [Singapore]
# 4                                 [Singapore]
# 5                                 [Singapore]
# 6             [80 Bras Basah Road, Singapore]
# 7                         [179101, Singapore]
# 8               [Marina bay sands, Singapore]
# 9                   [Fullerton Rd, Singapore]
# 10                                [Singapore]
# 11                                [Singapore]
# 12      [5 Raffles Avenue, 039797, Singapore]
# 13                                [Singapore]
# 14               [6 Raffles Blvd., Singapore]
# 15  [7 Raffles Boulevard (Marina), Singapore]
# 16                                [Singapore]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 1.2813332, 'lng':...      1.281333
# 1   [{'label': 'display', 'lat': 1.286801, 'lng': ...      1.286801
# 2   [{'label': 'display', 'lat': 1.280180160990135...      1.280180
# 3   [{'label': 'display', 'lat': 1.279713939349647...      1.279714
# 4   [{'label': 'display', 'lat': 1.279697, 'lng': ...      1.279697
# 5   [{'label': 'display', 'lat': 1.279528329559382...      1.279528
# 6   [{'label': 'display', 'lat': 1.293636, 'lng': ...      1.293636
# 7   [{'label': 'display', 'lat': 1.293512511970212...      1.293513
# 8   [{'label': 'display', 'lat': 1.282267807028707...      1.282268
# 9   [{'label': 'display', 'lat': 1.286377712140318...      1.286378
# 10  [{'label': 'display', 'lat': 1.2815793, 'lng':...      1.281579
# 11  [{'label': 'display', 'lat': 1.286153548140678...      1.286154
# 12  [{'label': 'display', 'lat': 1.289948, 'lng': ...      1.289948
# 13  [{'label': 'display', 'lat': 1.276589986697232...      1.276590
# 14  [{'label': 'display', 'lat': 1.292024477552945...      1.292024
# 15  [{'label': 'display', 'lat': 1.292205655140051...      1.292206
# 16  [{'label': 'display', 'lat': 1.292024392507780...      1.292024
#
#     location.lng location.postalCode  \
# 0     103.858924              038982
# 1     103.854436                 NaN
# 2     103.851480                 NaN
# 3     103.850444                 NaN
# 4     103.850430                 NaN
# 5     103.849589                 NaN
# 6     103.854296                 NaN
# 7     103.854290              179101
# 8     103.858513                 NaN
# 9     103.853207                 NaN
# 10    103.863621                 NaN
# 11    103.853035                 NaN
# 12    103.858022              039797
# 13    103.863812                 NaN
# 14    103.856457                 NaN
# 15    103.858138                 NaN
# 16    103.858014                 NaN
#
#                                                  name    referralId  \
# 0                                Laxury Magnum Hotels  v-1586276253
# 1                                      Merlion Hotels  v-1586276253
# 2                            Montigo Hotels & Resorts  v-1586276253
# 3      Aqua Voyage , A Member Of KOP Hotels & Resorts  v-1586276253
# 4                                KOP Hotels & Resorts  v-1586276253
# 5                           Franklyn Hotels & Resorts  v-1586276253
# 6                        RC Hotels Female Locker Room  v-1586276253
# 7                                  RC Hotels Tuckshop  v-1586276253
# 8                  Marine Bay Sands Hotel Storey 2113  v-1586276253
# 9                 Gym @ The Fullerton Hotel Singapore  v-1586276253
# 10                              Mahadria Hotel Serang  v-1586276253
# 11  East Garden Foyer @ The Fullerton Hotel Singapore  v-1586276253
# 12  Morton's The Steakhouse at Mandarin Oriental H...  v-1586276253
# 13              Marina bay sands VVIP Hotel singapore  v-1586276253
# 14                Marina Mandarin Hotel Swimming Pool  v-1586276253
# 15         Global Kitchen Pan Pacific Hotel Singapore  v-1586276253
# 16        Pacific Cafe @ Pan Pacific Hotel Singaporey  v-1586276253
#
#    venuePage.id
# 0     572011888
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %% [markdown]
# **Result matrix**
#
# | Location | Number of attractions | Number of restaurants | Number of bars/clubs | Number of 5* hotel | Sum of scores |
# | --- | --- | --- | --- | --- | --- |
# | **Marina Bay** | 1 | 6 | 9 | 17 | -1 |
# | **Sentosa** | 0 | 2 | 0 | 17 | -15 |

# %% [markdown]
# ## Discussion
#
# Based on the outcome of results, both location faced intense competition from other hotel operators. However, In Marina Bay area, there are more bars and restaurants for hotel guests. Therefore, Marina Bay is the preferred location for the new hotel.

# %% [markdown]
# ## Conclusion
#
# While this report made use of data from Foursquare to determine the preferred location based on a list of metrics, the popularity of Foursquare in Singapore is low, therefore, there might be limited data or inaccurate data that reflects the number of different establishments in the area. Further research can be done using data from more popular sources such as google map. However, this report stil
